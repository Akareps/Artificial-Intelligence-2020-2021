# %% [markdown]
# **Ονοματεπώνυμο: Ανδρέας Ακαρέπης**
#
# **Α.Μ.: 03117058**
#
# **Ονοματεπώνυμο: Κόντη Πολυξένη Ειρήνη**
#
# **Α.Μ.: 03117180**

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα ασχοληθείτε και θα εργαστείτε μόνο με το αρχείο movies_metadata.csv.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του αρχείου αυτού, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.).
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο train_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων (π.χ. 10, 20, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set). Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/gdrive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %% [markdown]
# # ΥΛΟΠΟΙΗΣΗ ΑΣΚΗΣΗΣ
#
# * Τρέξαμε τον κώδικα στο περιβάλλον του kaggle και προσαρμόσαμε τις εντολές που προορίζονταν για το google colab ώστε να τρέξουν σωστά.

# %%
path='../input/askhsh3/' #Αυτό είναι το path στο kaggle στο οποίο βρίσκονται τα αρχεία με τα δεδομένα 
                        #των ταινιών

# %%
#install swi-prolog
# !apt-get -y install software-properties-common
#!apt-add-repository -enter ppa:swi-prolog/stable
# !apt-get -y update
# !apt-get -y install swi-prolog
#install pyswip
# !pip install pyswip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python3-software-properties
# The following packages will be upgraded:
#   python3-software-properties software-properties-common
# 2 upgraded, 0 newly installed, 0 to remove and 104 not upgraded.
# Need to get 33.9 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 software-properties-common all 0.96.24.32.14 [10.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-software-properties all 0.96.24.32.14 [23.9 kB]
# Fetched 33.9 kB in 1s (51.8 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# (Reading database ... 110721 files and directories currently installed.)
# Preparing to unpack .../software-properties-common_0.96.24.32.14_all.deb ...
# Unpacking software-properties-common (0.96.24.32.14) over (0.96.24.32.12) ...
# Preparing to unpack .../python3-software-properties_0.96.24.32.14_all.deb ...
# Unpacking python3-software-properties (0.96.24.32.14) over (0.96.24.32.12) ...
# Setting up python3-software-properties (0.96.24.32.14) ...
# Setting up software-properties-common (0.96.24.32.14) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.1) ...
# Get:1 http://packages.cloud.google.com/apt gcsfuse-bionic InRelease [4114 B]
# Get:2 http://packages.cloud.google.com/apt cloud-sdk-bionic InRelease [6774 B]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://packages.cloud.google.com/apt cloud-sdk InRelease [6739 B]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:7 http://packages.cloud.google.com/apt cloud-sdk-bionic/main amd64 Packages [157 kB]
# Get:8 http://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [149 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1816 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [266 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2136 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1372 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [237 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [15.3 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [53.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2244 kB]
# Fetched 8716 kB in 2s (3584 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev bsdmainutils debhelper
#   dh-autoreconf dh-strip-nondeterminism gettext gettext-base groff-base
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libbsd-dev
#   libedit-dev libfile-stripnondeterminism-perl libgmp-dev libgmpxx4ldbl
#   libltdl-dev libmail-sendmail-perl libncurses5-dev libncursesw5-dev
#   libossp-uuid16 libpipeline1 libreadline-dev libsigsegv2
#   libsys-hostname-long-perl libtinfo-dev libtool m4 man-db po-debconf
#   swi-prolog-nox swi-prolog-x
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc wamerican | wordlist whois
#   vacation dh-make dwz gettext-doc libasprintf-dev libgettextpo-dev groff
#   gmp-doc libgmp10-doc libmpfr-dev libtool-doc ncurses-doc uuid readline-doc
#   gfortran | fortran95-compiler gcj-jdk m4-doc apparmor www-browser
#   libmail-box-perl elpa-ediprolog
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev bsdmainutils debhelper
#   dh-autoreconf dh-strip-nondeterminism gettext gettext-base groff-base
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libbsd-dev
#   libedit-dev libfile-stripnondeterminism-perl libgmp-dev libgmpxx4ldbl
#   libltdl-dev libmail-sendmail-perl libncurses5-dev libncursesw5-dev
#   libossp-uuid16 libpipeline1 libreadline-dev libsigsegv2
#   libsys-hostname-long-perl libtinfo-dev libtool m4 man-db po-debconf
#   swi-prolog swi-prolog-nox swi-prolog-x
# 0 upgraded, 36 newly installed, 0 to remove and 110 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 60.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 bsdmainutils amd64 11.1.2ubuntu1 [181 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 groff-base amd64 1.22.3-10 [1153 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpipeline1 amd64 1.5.0-1 [25.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 man-db amd64 2.8.3-2ubuntu0.1 [1019 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9644 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbsd-dev amd64 0.8.7-1ubuntu0.1 [150 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtinfo-dev amd64 6.1-1ubuntu1.18.04 [81.3 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libncurses5-dev amd64 6.1-1ubuntu1.18.04 [174 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libedit-dev amd64 3.1-20170329-1 [99.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmpxx4ldbl amd64 2:6.1.2+dfsg-2 [8964 B]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp-dev amd64 2:6.1.2+dfsg-2 [316 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl-dev amd64 2.4.6-2 [162 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libncursesw5-dev amd64 6.1-1ubuntu1.18.04 [199 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libossp-uuid16 amd64 1.6.2-1.5build4 [29.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libreadline-dev amd64 7.0-3 [133 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swi-prolog-nox amd64 7.6.4+dfsg-1build1 [3352 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swi-prolog-x amd64 7.6.4+dfsg-1build1 [2010 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swi-prolog amd64 7.6.4+dfsg-1build1 [15.3 kB]
# Fetched 13.5 MB in 3s (5381 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package bsdmainutils.
# (Reading database ... 110721 files and directories currently installed.)
# Preparing to unpack .../00-bsdmainutils_11.1.2ubuntu1_amd64.deb ...
# Unpacking bsdmainutils (11.1.2ubuntu1) ...
# Selecting previously unselected package groff-base.
# Preparing to unpack .../01-groff-base_1.22.3-10_amd64.deb ...
# Unpacking groff-base (1.22.3-10) ...
# Selecting previously unselected package libpipeline1:amd64.
# Preparing to unpack .../02-libpipeline1_1.5.0-1_amd64.deb ...
# Unpacking libpipeline1:amd64 (1.5.0-1) ...
# Selecting previously unselected package man-db.
# Preparing to unpack .../03-man-db_2.8.3-2ubuntu0.1_amd64.deb ...
# Unpacking man-db (2.8.3-2ubuntu0.1) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../04-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../05-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../06-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../07-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../08-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../09-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../10-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../11-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../12-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../13-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../14-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../20-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libbsd-dev:amd64.
# Preparing to unpack .../21-libbsd-dev_0.8.7-1ubuntu0.1_amd64.deb ...
# Unpacking libbsd-dev:amd64 (0.8.7-1ubuntu0.1) ...
# Selecting previously unselected package libtinfo-dev:amd64.
# Preparing to unpack .../22-libtinfo-dev_6.1-1ubuntu1.18.04_amd64.deb ...
# Unpacking libtinfo-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Selecting previously unselected package libncurses5-dev:amd64.
# Preparing to unpack .../23-libncurses5-dev_6.1-1ubuntu1.18.04_amd64.deb ...
# Unpacking libncurses5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Selecting previously unselected package libedit-dev:amd64.
# Preparing to unpack .../24-libedit-dev_3.1-20170329-1_amd64.deb ...
# Unpacking libedit-dev:amd64 (3.1-20170329-1) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../25-libgmpxx4ldbl_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../26-libgmp-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libltdl-dev:amd64.
# Preparing to unpack .../27-libltdl-dev_2.4.6-2_amd64.deb ...
# Unpacking libltdl-dev:amd64 (2.4.6-2) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../28-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../29-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libncursesw5-dev:amd64.
# Preparing to unpack .../30-libncursesw5-dev_6.1-1ubuntu1.18.04_amd64.deb ...
# Unpacking libncursesw5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Selecting previously unselected package libossp-uuid16:amd64.
# Preparing to unpack .../31-libossp-uuid16_1.6.2-1.5build4_amd64.deb ...
# Unpacking libossp-uuid16:amd64 (1.6.2-1.5build4) ...
# Selecting previously unselected package libreadline-dev:amd64.
# Preparing to unpack .../32-libreadline-dev_7.0-3_amd64.deb ...
# Unpacking libreadline-dev:amd64 (7.0-3) ...
# Selecting previously unselected package swi-prolog-nox.
# Preparing to unpack .../33-swi-prolog-nox_7.6.4+dfsg-1build1_amd64.deb ...
# Unpacking swi-prolog-nox (7.6.4+dfsg-1build1) ...
# Selecting previously unselected package swi-prolog-x.
# Preparing to unpack .../34-swi-prolog-x_7.6.4+dfsg-1build1_amd64.deb ...
# Unpacking swi-prolog-x (7.6.4+dfsg-1build1) ...
# Selecting previously unselected package swi-prolog.
# Preparing to unpack .../35-swi-prolog_7.6.4+dfsg-1build1_amd64.deb ...
# Unpacking swi-prolog (7.6.4+dfsg-1build1) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libltdl-dev:amd64 (2.4.6-2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libbsd-dev:amd64 (0.8.7-1ubuntu0.1) ...
# Setting up groff-base (1.22.3-10) ...
# Setting up libossp-uuid16:amd64 (1.6.2-1.5build4) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up libtinfo-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up libpipeline1:amd64 (1.5.0-1) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libncurses5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libncursesw5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Setting up libreadline-dev:amd64 (7.0-3) ...
# Setting up libedit-dev:amd64 (3.1-20170329-1) ...
# Setting up bsdmainutils (11.1.2ubuntu1) ...
# update-alternatives: using /usr/bin/bsd-write to provide /usr/bin/write (write) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/write.1.gz because associated file /usr/share/man/man1/bsd-write.1.gz (of link group write) doesn't exist
# update-alternatives: using /usr/bin/bsd-from to provide /usr/bin/from (from) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/from.1.gz because associated file /usr/share/man/man1/bsd-from.1.gz (of link group from) doesn't exist
# Setting up libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up autoconf (2.69-11) ...
# Setting up swi-prolog-nox (7.6.4+dfsg-1build1) ...
# update-alternatives: using /usr/bin/swipl to provide /usr/bin/prolog (prolog) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/prolog.1.gz because associated file /usr/share/man/man1/swipl.1.gz (of link group prolog) doesn't exist
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/automake.1.gz because associated file /usr/share/man/man1/automake-1.15.1.gz (of link group automake) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/aclocal.1.gz because associated file /usr/share/man/man1/aclocal-1.15.1.gz (of link group automake) doesn't exist
# Setting up man-db (2.8.3-2ubuntu0.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Building database of manual pages ...
# Setting up po-debconf (1.0.20) ...
# Setting up swi-prolog-x (7.6.4+dfsg-1build1) ...
# Setting up swi-prolog (7.6.4+dfsg-1build1) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running mktexlsr. This may take some time... done.
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for install-info (6.5.0.dfsg.1-2) ...
# Collecting pyswip
#   Downloading pyswip-0.2.10-py2.py3-none-any.whl (27 kB)
# Installing collected packages: pyswip
# Successfully installed pyswip-0.2.10
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog
#import nltk
#nltk.download('stopwords')

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0       2009  United States of America      James Cameron      Zoe Saldana
# 1       2007  United States of America     Gore Verbinski    Orlando Bloom
# 2       2015            United Kingdom         Sam Mendes  Christoph Waltz
# 3       2012  United States of America  Christopher Nolan    Michael Caine
# 4       2012  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %% [markdown]
# # ****ΜΕΡΟΣ 1Α****

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
#τα χαρακτηριστικά των ταινιών που περιείχαν το string 'UNK' και άρα αρχικά ήταν null δεν τα 
#συμπεριλαμβάνουμε στον κόσμο μας.
literals = []
#Στο dictionary ratings_crowd αποθηκεύτηκε η βαθμολογία του κοινού για κάθε ταινία. Τα δεδομένα αυτά χρειάστηκαν για περαιτέρω πειραματισμό
#στο μέρος 3 της εργασίας.
ratings_crowd = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, "movie_title"))
  literals.append("movie('"+movie_title+"')")
  for genre in getattr(row, 'genres').split("|"):
    genre = clean_text(genre)
    if genre != 'UNK':
      literals.append("genre('"+ movie_title +"','"+ genre +"')")
  flag = False
  for plot_keyword in getattr(row,'plot_keywords').split("|"):
    plot_keyword = clean_text(plot_keyword)
    if plot_keyword == "black and white":
      flag = True
    if plot_keyword != 'UNK':
      literals.append("plot_keywords('"+movie_title+"','"+plot_keyword+"')")
  if flag: 
    literals.append("black_and_white('"+movie_title+"')")
  else:
    literals.append("coloured('"+movie_title+"')")
  
  lang = clean_text(getattr(row,'language'))
  if lang != 'UNK':
    literals.append("language('"+movie_title+"','"+lang+"')")

  duration = clean_text(str(getattr(row,'duration')))
  if duration != 'UNK':
    literals.append("duration('"+movie_title+"',"+duration+")")
  title_year = clean_text(str(getattr(row,'title_year')))
  if title_year != 'UNK':
    literals.append("title_year('"+movie_title+"',"+title_year+")")

  country = getattr(row,'country')
  if country != 'UNK':
    literals.append("country('"+movie_title+"','"+country+"')")

  vote_average = clean_text(str(getattr(row,'vote_average')))
  if vote_average != 'UNK':
    ratings_crowd[movie_title] = vote_average
    literals.append("ratings('"+movie_title+"',"+vote_average+")")

  director = clean_text(getattr(row,'director_name'))
  if director != 'UNK':
    literals.append("director_name('"+movie_title+"','"+director+"')")
  actor1 = clean_text(getattr(row,'actor_1_name'))
  if actor1 != 'UNK':
    literals.append("actor1('"+movie_title+"','"+actor1+"')")
  actor2 = clean_text(getattr(row,'actor_2_name'))
  if actor1 != 'UNK':
    literals.append("actor2('"+movie_title+"','"+actor2+"')")
  actor3 = clean_text(getattr(row,'actor_3_name'))
  if actor3 != 'UNK':
    literals.append("actor3('"+movie_title+"','"+actor3+"')")

#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)

# %% [markdown]
# # **ΜΕΡΟΣ 1Β**

# %%
#Βασικά queries

#Κανόνας που δείχνει αν δύο ταινίες κυκλοφόρησαν σε κοντινές χρονολογίες, συγκεκριμένα στην ίδια 
#πενταετία
prolog.assertz('''(close_year(X,Y):-
                                    title_year(X,T1),
                                    movie(Y),
                                    Y \= X,
                                    title_year(Y,T2),
                                    abs(T2-T1) =< 5)''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν διάρκειες με διαφορά το πολύ μισής ώρας
prolog.assertz('''(close_duration(X,Y):-
                                        duration(X,T1),
                                        movie(Y),
                                        X \= Y,
                                        duration(Y,T2),
                                        abs(T2-T1) < 30.0)''')
#Κανόνας που δείχνει αν δύο ταίνιες γυρίστηκαν στην ίδια χώρα
prolog.assertz('''(same_country(X,Y):-
                                      country(X,C),
                                      movie(Y),
                                      X \= Y,
                                      country(Y,C))''')
#Κανόνας που δείχνει αν δύο ταίνιες χρησιμοποιούν την ίδια γλώσσα
prolog.assertz('''(common_language(X,Y):-
                                         movie(Y),
                                         X \= Y,
                                         language(X,L),
                                         language(Y,L))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν τον ίδιο σκηνοθέτη
prolog.assertz('''(common_director(X,Y):-
                                       movie(Y),
                                       director_name(X,DIR),
                                       director_name(Y,DIR),
                                       X \= Y)''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν όλους τους βασικούς ηθοποιούς κοινούς
prolog.assertz('''(common_all_actors(X,Y):-
                                          movie(Y),
                                          X \= Y,
                                          actor1(X,A1),
                                          actor2(X,A2),
                                          actor3(X,A3),
                                          (actor1(Y,A1);
                                          actor2(Y,A1);
                                          actor3(Y,A1)),
                                          (actor1(Y,A2);
                                          actor2(Y,A2);
                                          actor3(Y,A2)),
                                          (actor1(Y,A3);
                                          actor2(Y,A3);
                                          actor3(Y,A3)))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν 2 βασικούς ηθοποιούς κοινούς
prolog.assertz('''(common_2_actors(X,Y):-
                                         movie(Y),
                                         X \= Y,
                                         actor1(X,A1),
                                         actor2(X,A2),
                                         actor3(X,A3),
                                         (((actor1(Y,A1);
                                          actor2(Y,A1);
                                          actor3(Y,A1)),
                                         (actor1(Y,A2);
                                          actor2(Y,A2);
                                          actor3(Y,A2)));
                                         ((actor1(Y,A1);
                                          actor2(Y,A1);
                                          actor3(Y,A1)),
                                         (actor1(Y,A3);
                                          actor2(Y,A3);
                                          actor3(Y,A3)));
                                         ((actor1(Y,A2);
                                          actor2(Y,A2);
                                          actor3(Y,A2)),
                                         (actor1(Y,A3);
                                          actor2(Y,A3);
                                          actor3(Y,A3)))))''')

#Κανόνας που δείχνει αν δύο ταίνιες έχουν 1 βασικό ηθοποιό κοινό
prolog.assertz('''(common_1_actor(X,Y):-
                                        movie(Y),
                                        X \= Y,
                                        actor1(X,A1),
                                        actor2(X,A2),
                                        actor3(X,A3),
                                        ((actor1(Y,A1);
                                        actor2(Y,A1);
                                        actor3(Y,A1));
                                        (actor1(Y,A2);
                                        actor2(Y,A2);
                                        actor3(Y,A2));
                                        (actor1(Y,A3);
                                        actor2(Y,A3);
                                        actor3(Y,A3))))''')
#Οι παρακάτω κανόνες δείχνουν κατά πόσο μία ταινία έχει καλές κριτικές με βάση το κοινό, μέτριες ή κακές.
# Σε σύστημα βέβαια που προτείνει ταινίες με βάση τις προτιμήσεις ενός συ7γκεκριμένου χρήστη θεωρήηθκε
#πιο λογικό να χρησιμοποιηθεί ο τέταρτος κανόνας που δείχνει κατά πόσο 2 ταινίες έχουν παρόμοιες κριτικές 
#κοινού
prolog.assertz('''(good_ratings(X):-
                                    ratings(X,Y),
                                    Y >= 8.0)''')
prolog.assertz('''(mediocre_ratings(X):-
                                         ratings(X,T),
                                         T >= 7.0,
                                         T < 8.0)''')
prolog.assertz('''(bad_ratings(X):-
                                   ratings(X,T),
                                   T >= 6.0,
                                   T < 7.0)''')
prolog.assertz('''(similar_ratings(X,Y):-
                                        ratings(X,T1),
                                        ratings(Y,T2),
                                        abs(T1-T2) =< 3)''')

#Κανόνας που δείχνει αν δύο ταίνιες είναι και οι δύο ασπρόμαυρες ή και οι δύο έγχρωμες.
prolog.assertz('''(coloured_or_not(X,Y):-
                                         black_and_white(X)->
                                         (movie(Y),
                                         black_and_white(Y));
                                         coloured(X)->
                                         (movie(Y),
                                         coloured(Y)))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινό 1 genre
prolog.assertz('''(common_1_genre(X,Y):-
                                        genre(X,G1),
                                        movie(Y),
                                        genre(Y,G1))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 2 genre
prolog.assertz('''(common_2_genre(X,Y):-
                                        genre(X,G1),
                                        genre(X,G2),
                                        G1 \= G2,
                                        movie(Y),
                                        genre(Y,G1),
                                        genre(Y,G2))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 3 genre
prolog.assertz('''(common_3_genre(X,Y):-
                                        genre(X,G1),
                                        genre(X,G2),
                                        genre(X,G3),
                                        G1 \= G2,
                                        G1 \= G3,
                                        G2 \= G3,
                                        movie(Y),
                                        genre(Y,G1),
                                        genre(Y,G2),
                                        genre(Y,G3))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 4 genre
prolog.assertz('''(common_4_genre(X,Y):-
                                        genre(X,G1),
                                        genre(X,G2),
                                        genre(X,G3),
                                        genre(X,G4),
                                        G1 \= G2,
                                        G1 \= G3,
                                        G2 \= G3,
                                        G1 \= G4,
                                        G2 \= G4,
                                        G3 \= G4,
                                        movie(Y),
                                        genre(Y,G1),
                                        genre(Y,G2),
                                        genre(Y,G3),
                                        genre(Y,G4))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 5 genre
prolog.assertz('''(common_5_genre(X,Y):-
                                        genre(X,G1),
                                        genre(X,G2),
                                        genre(X,G3),
                                        genre(X,G4),
                                        genre(X,G5),
                                        G1 \= G2,
                                        G1 \= G3,
                                        G2 \= G3,
                                        G1 \= G4,
                                        G2 \= G4,
                                        G3 \= G4,
                                        G1 \= G5,
                                        G2 \= G5,
                                        G3 \= G5,
                                        G4 \= G5,
                                        movie(Y),
                                        genre(Y,G1),
                                        genre(Y,G2),
                                        genre(Y,G3),
                                        genre(Y,G4),
                                        genre(Y,G5))''')

#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 2 plot_keywords
prolog.assertz('''(common_2_keywords(X,Y):-
                                          plot_keywords(X,P1),
                                          plot_keywords(X,P2),
                                          P1 \= P2,
                                          movie(Y),
                                          X \= Y,
                                          plot_keywords(Y,P1),
                                          plot_keywords(Y,P2))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 3 plot_keywords
prolog.assertz('''(common_3_keywords(X,Y):-
                                          plot_keywords(X,P1),
                                          plot_keywords(X,P2),
                                          plot_keywords(X,P3),
                                          P1 \= P2,
                                          P1 \= P3,
                                          P2 \= P3,
                                          movie(Y),
                                          X \= Y,
                                          plot_keywords(Y,P1),
                                          plot_keywords(Y,P2),
                                          plot_keywords(Y,P3))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 4 plot_keywords
prolog.assertz('''(common_4_keywords(X,Y):-
                                          plot_keywords(X,P1),
                                          plot_keywords(X,P2),
                                          plot_keywords(X,P3),
                                          plot_keywords(X,P4),
                                          P1 \= P2,
                                          P1 \= P3,
                                          P2 \= P3,
                                          P1 \= P4,
                                          P2 \= P4,
                                          P3 \= P4,
                                          movie(Y),
                                          X \= Y,
                                          plot_keywords(Y,P1),
                                          plot_keywords(Y,P2),
                                          plot_keywords(Y,P3),
                                          plot_keywords(Y,P4))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 5 plot_keywords
prolog.assertz('''(common_5_keywords(X,Y):-
                                          plot_keywords(X,P1),
                                          plot_keywords(X,P2),
                                          plot_keywords(X,P3),
                                          plot_keywords(X,P4),
                                          plot_keywords(X,P5),
                                          P1 \= P2,
                                          P1 \= P3,
                                          P2 \= P3,
                                          P1 \= P4,
                                          P2 \= P4,
                                          P3 \= P4,
                                          P1 \= P5,
                                          P2 \= P5,
                                          P3 \= P5,
                                          P4 \= P5,
                                          movie(Y),
                                          X \= Y,
                                          plot_keywords(Y,P1),
                                          plot_keywords(Y,P2),
                                          plot_keywords(Y,P3),
                                          plot_keywords(Y,P4),
                                          plot_keywords(Y,P5))''')
#Κανόνας που δείχνει αν δύο ταίνιες έχουν κοινά 6 plot_keywords
prolog.assertz('''(common_6_keywords(X,Y):-
                                          plot_keywords(X,P1),
                                          plot_keywords(X,P2),
                                          plot_keywords(X,P3),
                                          plot_keywords(X,P4),
                                          plot_keywords(X,P5),
                                          plot_keywords(X,P6),
                                          P1 \= P2,
                                          P1 \= P3,
                                          P2 \= P3,
                                          P1 \= P4,
                                          P2 \= P4,
                                          P3 \= P4,
                                          P1 \= P5,
                                          P2 \= P5,
                                          P3 \= P5,
                                          P4 \= P5,
                                          P1 \= P6,
                                          P2 \= P6,
                                          P3 \= P6,
                                          P4 \= P6,
                                          P5 \= P6,
                                          movie(Y),
                                          X \= Y,
                                          plot_keywords(Y,P1),
                                          plot_keywords(Y,P2),
                                          plot_keywords(Y,P3),
                                          plot_keywords(Y,P4),
                                          plot_keywords(Y,P5),
                                          plot_keywords(Y,P6))''')

# %%
q = prolog.query("close_year('Pirates of the Caribbean: At Worlds End',M)")
s = set()
for soln in q:
    m = soln['M'] 
    if m not in s:
        s.add(soln['M'])
q.close()
i = 0
print(len(s))
for sol in s:
   print(sol)
   i = i+1
   if i > 10:
    break
# Out:
# 2354
# Rent
# Blue Crush
# Talladega Nights: The Ballad of Ricky Bobby
# Divine Secrets of the Ya-Ya Sisterhood
# Troll Hunter
# Silver Linings Playbook
# Sorority Boys
# X-Men: The Last Stand
# Fat, Sick & Nearly Dead
# Black November
# Four Brothers

# %% [markdown]
# * Όλοι οι κανόνες που δημιουργήθηκαν στο μέρος 1Β εκτελέστηκαν με όρισμα μία τυχαία ταινία από το αρχείο movies_metadata.csv για να ελεγχθεί η ορθότητά τους και η αποδοτικότητά τους ως προς τον χρόνος που χρειάστηκαν και το πόσες από τις 4000 ταινίες πρότειναν.
# * Γενικά παρατηρήθηκε ότι κανόνες όπως το common_language και same_country προτείνουν αρκετές ταινίες, καθώς οι περισσότερες χρησιμοποιούν ως γλώσσα τα αγγλικά και γυρίζονται στην Αμερική. Συνεπώς αν και χρήσιμα δεν μπορούν αν θεωρηθούν από μόνα τους πλήρως καθοριστικά για την εύρεση όμοιων ταινιών.
# * Επιπλέον οι κανόνες που βρίσκουν ταινίες με όμοια genre και plot_keywords, με την αύξηση του αριθμού των κοινών στοιχείων αυξάνεται κατά πολύ ο χρόνος εκτέλεσης τους, ενώ συγχρόνως οι ταινίες που επιστρέφουν είναι πολύ λίγες και τις περισσότερες φορές 0. Συνεπώς, σε έναν recommender πιθανόν να μην έχει ιδιαίτερο νόημα να χρησιμοποιήσουμε τους κανόνες "common_5_genre", "common_5_keywords" και "common_6_keywords".

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
#Με χρήση των κανόνων του ερωτήματος 1Β δημιουργήθηκαν οι ακόλουθες συναρτήσεις ομοιότητας. 
#Οι συναρτήσεις αυτές είναι ενδεικτικές και σε καμία περίπτωση εξαντλητικές.
#Είναι επιπλέον κλιμακούμενης ομοιότητας με 2 ταινίες να είναι λίγο όμοιες αν προτείνονται 
#από την find_sim_1 και πάρα πολύ όμοιες αν πρότεινονται από την find_sim_20.
#Δεν χρησιμοποιήθηκαν όλοι οι κανόνες του προηγούμενου ερωτήματος, καθώς για το σύνολο των ταινιών 
#που εξετάζονται η προσθήκη τους δεν θα προκαλούσε σημαντική διαφορά στο αποτέλεσμα, ενώ αντίθετα
#θα αύξανε τον χρόνο εκτέλεσής του.
prolog.assertz('''(find_sim_1(X,Y):-
                                    common_1_actor(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_2(X,Y):-
                                    common_director(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_3(X,Y):-
                                    common_2_actors(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_4(X,Y):-
                                    common_1_genre(X,Y))''')
prolog.assertz('''(find_sim_5(X,Y):-
                                    common_director(X,Y),
                                    common_1_actor(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_6(X,Y):-
                                    common_2_genre(X,Y))''')
prolog.assertz('''(find_sim_7(X,Y):- 
                                    common_1_genre(X,Y),
                                    common_2_keywords(X,Y))''')
prolog.assertz('''(find_sim_8(X,Y):-
                                    common_all_actors(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_9(X,Y):-
                                    common_director(X,Y),
                                    common_2_actors(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_10(X,Y):-
                                    common_1_genre(X,Y),
                                    common_2_keywords(X,Y),
                                    common_director(X,Y),
                                    common_1_actor(X,Y))''')
prolog.assertz('''(find_sim_11(X,Y):- 
                                    common_2_genre(X,Y),
                                    common_3_keywords(X,Y))''')
prolog.assertz('''(find_sim_12(X,Y):-
                                    common_3_genre(X,Y))''')
prolog.assertz('''(find_sim_13(X,Y):-
                                    common_4_genre(X,Y))''')
prolog.assertz('''(find_sim_14(X,Y):- 
                                    common_3_genre(X,Y),
                                    common_2_keywords(X,Y))''')
prolog.assertz('''(find_sim_15(X,Y):-
                                    common_2_genre(X,Y),
                                    common_2_keywords(X,Y),
                                    common_director(X,Y),
                                    common_2_actors(X,Y),
                                    common_language(X,Y))''')
prolog.assertz('''(find_sim_16(X,Y):-
                                    common_director(X,Y),
                                    common_all_actors(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y))''')
prolog.assertz('''(find_sim_17(X,Y):- 
                                    common_4_genre(X,Y),
                                    common_3_keywords(X,Y))''')
prolog.assertz('''(find_sim_18(X,Y):-
                                    common_director(X,Y),
                                    common_all_actors(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y),
                                    close_year(X,Y),
                                    close_duration(X,Y))''')
prolog.assertz('''(find_sim_19(X,Y):- 
                                    common_5_genre(X,Y),
                                    common_3_keywords(X,Y))''')
prolog.assertz('''(find_sim_20(X,Y):-
                                    common_2_genre(X,Y),
                                    common_2_keywords(X,Y),
                                    common_director(X,Y),
                                    common_all_actors(X,Y),
                                    common_language(X,Y),
                                    same_country(X,Y),
                                    similar_ratings(X,Y))''')
N = 20

# %% [markdown]
# Στη συνάρτηση recommender που ακολουθεί καλούμε τις συναρτήσεις από αυτήν με την μεγαλύτερη ομοιότητα (find_sim_20) σε αυτή με την μικρότερη ομοιότητα (find_sim_1). Τις αποθηκεύουμε σε μία λίστα και κάθε φορά που έχουμε αποθηκεύσει όλες τις ταινίες που πρότεινε μία συνάρτηση αποθηκεύουμε και το όνομα της συνάρτησης που την πρότεινε. Φροντίζουμε μάλιστα ώστε ταινίες που έχουν ήδη προταθεί να μην λαμβάνονται υπόψιν όταν τις προτείνει επόμενη συνάρτηση μικρότερου  βαθμού ομοιότητας.

# %%
def recommender(movie):
  s = set()
  answers = []
  i = N
  while i > 0:
    s1 = set()
    q = prolog.query("find_sim_"+str(i)+"('" + movie +"',M)")
    for soln in q:
        m = soln['M'] 
        if m not in s:
            s.add(soln['M'])
            s1.add(soln['M'])
    q.close()
    for sol in s1:
      answers.append(sol)
    answers.append('find_sim_'+str(i))
    i = i-1
  return answers

# %%
answers = recommender('Tangled')
for i in range(20):
    print(answers[i])
print(len(answers))

# %% [markdown]
# find_sim_20
#
# find_sim_19
#
# find_sim_18
#
# find_sim_17
#
# find_sim_16
#
# find_sim_15
#
# find_sim_14
#
# find_sim_13
#
# find_sim_12
#
# The Princess and the Frog
#
# The Smurfs
#
# Pocahontas
#
# Aladdin
#
# Toy Story 3
#
# Frozen
#
# find_sim_11
#
# find_sim_10
#
# find_sim_9
#
# find_sim_8
#
# Ella Enchanted
#
# 580

# %% [markdown]
# Εκτελέσαμε την συνάρτηση recommender για τυχαίες ταινίες για να βεβαιωθούμε ότι δίνει λογικά αποτελέσματα και σε καλό χρόνο.
#
# Παρατηρήθηκε ότι οι συναρτήσεις μεγάλης ομοιότητας σπάνια έδιναν κάποιο αποτέλεσμα. Το γεγονός αυτό οφείλεται κυρίως στο ότι σε ένα σχετικά μικρό σύνολο ταινιών, όπως αυτό που εξετάζεται στην άσκηση, δεν υπάρχουν ταινίες με τόσο πολλά όμοια στοιχεία. Ωστόσο, κρίθηκε ότι η υλοποίησή τους ήταν απαραίτητη καθώς σε πραγματικές συνθήκες οι συναρτήσεις αυτές θα επηρέαζαν θετικά την απόδοση του συστήματος.
#
# Υποσημείωση: Tο kaggle, όταν κατεβάζουμε ένα αρχείο, δεν αποθηκεύει πάντα τα αποτελέσματα μίας εκτέλεσης. Στην προηγούμενη συνάρτηση έγινε αναγκαστικά καταγραφή των αποτελεσμάτων σε μορφή markdown.

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %% [markdown]
# * Έχοντας, πλέον, φτιάξει τη συνάρτηση recommender έπρεπε να διαμορφώσουμε τα βάρη τόσο των βαθμών που είχε δώσει ο χρήστης στις ταινίες του training set όσο και των συνάρτησεων ομοιότητας.
# * Αρχικά, τα βάρη των συναρτήσεων ομοιότητας, όπως διαμορφώθηκαν ύστερα από λίγες δοκιμές στην αρχή της άσκησης, διαπιστώθηκε ότι ήταν αρκετά αντιπροσωπευτικά και για τον λόγο αυτό δεν αποτέλεσαν το επίκεντρο των πειραματισμών.
# * Στη συνέχεια βέβαια, στις πρώτες δοκιμές, που έγιναν, το precision προέκυπτε ίσο με 0.5 και το recall ίσο με 1, τιμές που υποδεικνύουν ότι η συνάρτηση δεν κάνει ιδιαίτερη διαλογή ταινιών και ουσιαστικά τις προτείνει όλες. Βασικός στόχος άλλωστε ήταν οι δύο παράμετροι να είναι όσο πιο κοντά γινόταν ώστε όσο περισσότερο εκπαιδεύεται το σύστημα (χωρίς φυσικά να φτάνουμε στην περίπτωση του overfitting) τόσο να αυξάνονται παράλληλα και οι δύο μετρικές.
# * Ύστερα από επιπλέον πειραματισμούς που αφορούσαν κυρίως τα βάρη της βαθμολογίας του χρήστη παρατηρήθηκε ότι αν τις βαθμολογίες του χρήστη τις λαμβάναμε υπόψιν μας ως πραγματικούς αριθμούς και όχι ως ακεραίους (όπως ήταν αρχικά στην άσκηση), τότε προέκυπταν πιο ομοιόμορφα αποτελέσματα. Δώσαμε, δηλαδή, επιπλέον βάρη για τις βαθμολογίες 0.5, 1.5, 2.5, 3.5 και 4.5.
# * Τέλος, έγιναν διάφορες δοκιμές για να βρεθεί η σωστή συνθήκη για το αν μία ταινία θα πρέπει να προταθεί στον χρήστη ή όχι. Εν τέλη, βέβαια, τα βάρη που είχαν ήδη διαμορφωθεί δούλευαν καλύτερα για την συνθήκη rating>0.
# * Στο πλαίσιο της έρευνας και σε σημείο που ξεφεύγει από τα ακριβή όρια της άσκησης, στο σημείο που μία ταινία επιλέγεται για το αν πρέπει να προταθεί στον χρήστη ή όχι, προστέθηκε μία επιπλέον συνθήκη που απέρριπτε ταινίες που είχαν βαθμολογία κοινού από μία συγκεκριμένη τιμή και κάτω. Το μόνο αποτέλεσμα που είναι άξιο λόγου ήταν αυτό της απόρριψης ταινιών με βαθμό από 6 και κάτω (το οποίο είχε {'presicion' = 0.6037735849056604, 'recall'= 0.4444444444444444, 'f1'= 0.5119999999999999), αλλά ακόμα και αυτό ήταν χειρότερο του τελικού αποτελέσματος της άσκησης. Από το χαμηλό recall, μάλιστα, έγινε αντιλληπτό ότι πολλές φορές οι κριτκές του κοινού δεν αντιπροσωπεύουν τις προσωπικές προτιμήσεις του κάθε χρήστη.

# %%
movie_score = {}

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score

rating_weights = {0.5:-5.5, 1.0:-3.8, 1.5:-3.3, 2.0:-2.5, 2.5:-1.5, 3.0:-0.8, 3.5:1.0, 4.0:2.0, 4.5:2.5, 5.0:3.0 }
score_weights = {0:0, 1:0.1, 2:0.2, 3:0.2, 4:0.5, 5:1, 6: 1.5, 7:1.5, 8:2, 9:2, 10:2.5, 11:2.5, 12:3, 13:4, 14:4, 15:5, 16:5, 17:5, 18:6, 19:6, 20:7.5}

# ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, start=0, end = -1, movie_score = {}):
    if end == -1:
        end = len(ratings)

    ratings = ratings.iloc[range(start, end)]
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = recommender(movie)
        i = N
        for similar_movie in similar_movies:
            if similar_movie == 'find_sim'+str(i):
              i = i-1
            elif similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[rating] * score_weights[i]
            else:
                movie_score[similar_movie] += rating_weights[rating] * score_weights[i] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score : #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) 
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))
    return real, pred
def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %%
train_ratings = pd.read_csv(path+"train_ratings.csv")
test_ratings = pd.read_csv(path+"test_ratings.csv")

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 0, 10, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# {'precision': 0.5166666666666667, 'recall': 0.4305555555555556, 'f1': 0.4696969696969697}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10, 20, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# {'precision': 0.5064935064935064, 'recall': 0.5416666666666666, 'f1': 0.523489932885906}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 20, 30, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# {'precision': 0.5166666666666667, 'recall': 0.4305555555555556, 'f1': 0.4696969696969697}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30, 50, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# {'precision': 0.5064935064935064, 'recall': 0.5416666666666666, 'f1': 0.523489932885906}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights,start = 50,movie_score= movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# {'precision': 0.5316455696202531, 'recall': 0.5833333333333334, 'f1': 0.5562913907284769}

# %% [markdown]
# # Παρατηρήσεις:
# * Στην αρχή του training, μέχρι και τις πρώτες 50 ταινίες, οι μετρικές είχαν αρκετά χαμηλές τιμές και δεν ακολουθούσαν σαφή αύξουσα σειρά με την αύξηση του training set. Σημαντική διαφορά παατηρήθηκε όταν το σύστημα εκπαιδεύτηκε και με τις 100 ταινίες.
# * Οι τελικές μετρικές παρ'όλο που δεν είναι ούτε αυτές πολύ υψηλές, παρουσιάζουν ομοιομορφία μεταξύ τους και υποδηλώνουν ότι πρόκειται για ένα σύστημα που κάνει επαρκή διαλογή των ταινιών -δεν προτείνει δηλαδή στον χρήστη όλες τις ταινίες αλλά τις φιλτράρει σε ικανοποιητικό βαθμό- και καταφέρνει να του αρέσουν πάνω από τις μισές ταινίες που του προτείνει.
# * Από την συμπεριφορά του συστήματος κρίνεται ότι αν αυξηθεί ακόμα περισσότερο το πλήθος των ταινιών, με τις οποίες γίνεται training, οι παράμετροι θα φτάσουν και οι δύο σε αρκετά υψηλό επίπεδο.
